# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

kf = '.'
lcset_name = 'train'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe'
methods = [
    'linear-fstw',
    'bspline-fstw',
    'spm-mle-fstw',
    'spm-mle-estw',
    'spm-mcmc-fstw',
    'spm-mcmc-estw',
    ]

# %%
for method in methods:
    any_incorrects_fittings = sms.get_any_incorrects_fittings(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - any_incorrects_fittings={len(any_incorrects_fittings)} #')
    
for method in methods:
    all_incorrects_fittings = sms.get_all_incorrects_fittings(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - all_incorrects_fittings={len(all_incorrects_fittings)} #')
# Out:
# method=linear-fstw - any_incorrects_fittings=111 #
# method=bspline-fstw - any_incorrects_fittings=296 #
# method=spm-mle-fstw - any_incorrects_fittings=111 #
# method=spm-mle-estw - any_incorrects_fittings=111 #
# method=spm-mcmc-fstw - any_incorrects_fittings=133 #
# method=spm-mcmc-estw - any_incorrects_fittings=101 #
# method=linear-fstw - all_incorrects_fittings=1 #
# method=bspline-fstw - all_incorrects_fittings=81 #
# method=spm-mle-fstw - all_incorrects_fittings=1 #
# method=spm-mle-estw - all_incorrects_fittings=1 #
# method=spm-mcmc-fstw - all_incorrects_fittings=4 #
# method=spm-mcmc-estw - all_incorrects_fittings=5 #

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    xe_ptimes = sms.get_perf_times(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - xe_ptimes={xe_ptimes}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# method=linear-fstw - xe_ptimes=.862±.344
# method=bspline-fstw - xe_ptimes=.714±.235
# method=spm-mle-fstw - xe_ptimes=10.023±3.823
# method=spm-mle-estw - xe_ptimes=10.229±3.933
# method=spm-mcmc-fstw - xe_ptimes=64.681±6.406
# method=spm-mcmc-estw - xe_ptimes=66.531±7.499

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms
from flamingchoripan.latex.latex_tables import LatexTable

info_df = sms.get_info_dict(f'../save/ssne', methods, cfilename, kf, lcset_name)
latex_kwargs = {
    'caption':f'kf={kf}',
    'label':'???',
    #'bold_criteriums':{c:'max' if ('%' in c or 'fits-n' in c) else 'min' for c in info_df.columns},
    #'custom_tabular_align':'l|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]),
    #'custom_tabular_align':'l|c|ccc|ccc|ccc',
}
latex_table = LatexTable(info_df, **latex_kwargs)
print(latex_table)
info_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 1164
# 1164
# 1164
# 1164
# 1164
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9f1251cdea49> in <module>
#       6 kf = 0
#       7 #kf = '.'
# ----> 8 info_df = sms.get_info_dict(f'../save/ssne', methods, cfilename, kf, lcset_name)
#       9 latex_kwargs = {
#      10     'caption':f'kf={kf}',
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/synth_method_statistics.py in get_info_dict(rootdir, methods, cfilename, kf, lcset_name, band_names)
#      98         for method in methods:
#      99                 _rootdir = f'{rootdir}/{method}/{cfilename}'
# --> 100                 files, files_ids = fcfiles.gather_files_by_kfold(_rootdir, kf, lcset_name)
#     101                 print(len(files_ids))
#     102                 trace_time = [f()['segs'] for f in files]
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in gather_files_by_kfold(rootdir, kf, kf_set, id_key, key_key_separator, key_value_separator, fext, kf_str, create_dir)
#     408                         key_key_separator,
#     409                         key_value_separator,
# --> 410                         fext,
#     411 			)
#     412         return files, files_ids
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in gather_files_by_id(rootdir, id_key, key_key_separator, key_value_separator, fext)
#     344         if id_key is None:
#     345 		files = gather_files(rootdir,
# --> 346                         fext,
#     347 			)
#     348                 files_ids = [f.cfilename for f in files]
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in gather_files(rootdir, fext)
#     334 	):
#     335         filedirs = get_filedirs(rootdir, fext=fext)
# --> 336         return [PFile(filedir) for filedir in filedirs]
#     337
#     338 def gather_files_by_id(rootdir,
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in <listcomp>(.0)
#     334 	):
#     335         filedirs = get_filedirs(rootdir, fext=fext)
# --> 336         return [PFile(filedir) for filedir in filedirs]
#     337
#     338 def gather_files_by_id(rootdir,
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in __init__(self, filedir, file, verbose)
#     264                 self.set_file(file)
#     265                 self.verbose = verbose
# --> 266                 self.reset()
#     267
#     268         def set_filedir(self, filedir):
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in reset(self)
#     284                 if self.file is None:
#     285                         if not self.disk_size is None: # file exists in disk
# --> 286                                 self.load()
#     287                         else:
#     288                                 raise Exception(f'no PFile.file and {self.filedir} does not exist in disk')
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in load(self)
#     322
#     323         def load(self):
# --> 324                 file = load_pickle(self.filedir)
#     325                 self.set_file(file)
#     326                 self.reset()
#
# ~/oscar/tesis/flaming-choripan/flamingchoripan/files.py in load_pickle(filedir, return_none_if_missing, verbose)
#     128
#     129         pickle_in = open(filedir,'rb')
# --> 130         file = pickle.load(pickle_in)
#     131         pickle_in.close()
#     132         return file
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    rank_bdict = sms.get_ranks(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(method)
    for b in rank_bdict.keys():
        print(rank_bdict[b])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
