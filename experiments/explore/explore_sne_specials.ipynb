# %%
import sys
sys.path.append('../../') # or just install the module
sys.path.append('../../../flaming-choripan') # or just install the module
sys.path.append('../../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = '../../../surveys-save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../../surveys-save)
# (0) - ../../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds - 5.164[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../../surveys-save)
# (0) - ../../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds - 5.164[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

filedir = '../../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds'

filedict = get_dict_from_filedir(filedir)
root_folder = filedict['*rootdir*']
cfilename = filedict['*cfilename*']
survey = filedict['survey']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# > loading: ../../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [raw - samples 2,047]
# (*) obs_samples: 65,174 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 28,351 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 38.9[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 36,823 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 50.9[days] - cadence(p50): 3.0[days]
#    |▏       | SLSN - 33/2,047 (1.61%)
#    |█████▉  | SNIa - 1,534/2,047 (74.94%)
#    |▍       | SNIbc - 103/2,047 (5.03%)
#    |█▍      | allSNII - 377/2,047 (18.42%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_train - samples 1,431]
# (*) obs_samples: 45,614 - min_len: 6 - max_dur: 444.7[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 19,841 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 38.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 25,773 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 50.0[days] - cadence(p50): 3.0[days]
#    |▏       | SLSN - 23/1,431 (1.61%)
#    |█████▉  | SNIa - 1,073/1,431 (74.98%)
#    |▍       | SNIbc - 72/1,431 (5.03%)
#    |█▍      | allSNII - 263/1,431 (18.38%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_val - samples 407]
# (*) obs_samples: 12,767 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 5,653 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 39.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 7,114 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 52.4[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 6/407 (1.47%)
#    |██████  | SNIa - 306/407 (75.18%)
#    |▍       | SNIbc - 20/407 (4.91%)
#    |█▍      | allSNII - 75/407 (18.43%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_test - samples 209]
# (*) obs_samples: 6,793 - min_len: 8 - max_dur: 398.9[days] - dur(p50): 53.1[days] - cadence(p50): 0.9[days]
# (g) obs_samples: 2,857 - min_len: 0 - max_dur: 396.9[days] - dur(p50): 38.5[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 3,936 - min_len: 0 - max_dur: 398.9[days] - dur(p50): 52.9[days] - cadence(p50): 2.9[days]
#    |▏       | SLSN - 4/209 (1.91%)
#    |█████▉  | SNIa - 155/209 (74.16%)
#    |▍       | SNIbc - 11/209 (5.26%)
#    |█▍      | allSNII - 39/209 (18.66%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,429]
# (*) obs_samples: 45,047 - min_len: 3 - max_dur: 444.7[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 19,618 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 38.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 25,429 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 49.9[days] - cadence(p50): 3.0[days]
#    |▏       | SLSN - 23/1,429 (1.61%)
#    |██████  | SNIa - 1,072/1,429 (75.02%)
#    |▍       | SNIbc - 72/1,429 (5.04%)
#    |█▍      | allSNII - 262/1,429 (18.33%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 407]
# (*) obs_samples: 12,480 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 5,543 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 39.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 6,937 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 52.4[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 6/407 (1.47%)
#    |██████  | SNIa - 306/407 (75.18%)
#    |▍       | SNIbc - 20/407 (4.91%)
#    |█▍      | allSNII - 75/407 (18.43%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [test - samples 209]
# (*) obs_samples: 6,725 - min_len: 7 - max_dur: 398.9[days] - dur(p50): 53.1[days] - cadence(p50): 0.9[days]
# (g) obs_samples: 2,839 - min_len: 0 - max_dur: 396.9[days] - dur(p50): 38.5[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 3,886 - min_len: 0 - max_dur: 398.9[days] - dur(p50): 52.9[days] - cadence(p50): 2.9[days]
#    |▏       | SLSN - 4/209 (1.91%)
#    |█████▉  | SNIa - 155/209 (74.16%)
#    |▍       | SNIbc - 11/209 (5.26%)
#    |█▍      | allSNII - 39/209 (18.66%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
import pandas as pd

load_filedir = f'../../data/{survey}/sne_specials.csv'
sne_specials_df = pd.read_csv(load_filedir)
print(sne_specials_df['outliers'].values)
sne_specials_df
# Out:
# ['ZTF20aapchqy' 'ZTF18aajkivu' 'ZTF20aacbwbm' 'ZTF19aamsetj'
#  'ZTF19abucwzt' 'ZTF18abrfchj' nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan]
#         outliers           vis  fit_ignored
# 0   ZTF20aapchqy  ZTF19aamhqej          NaN
# 1   ZTF18aajkivu  ZTF19aaojnrx          NaN
# 2   ZTF20aacbwbm  ZTF19abxjimu          NaN
# 3   ZTF19aamsetj  ZTF19adcecwu          NaN
# 4   ZTF19abucwzt  ZTF20aabqbxm          NaN
# 5   ZTF18abrfchj  ZTF20aadxvfj          NaN
# 6            NaN  ZTF20aaelulu          NaN
# 7            NaN  ZTF20aaewban          NaN
# 8            NaN  ZTF20aahmvfw          NaN
# 9            NaN  ZTF20aatznro          NaN
# 10           NaN  ZTF20aaxagnm          NaN
# 11           NaN  ZTF20aayknlo          NaN
# 12           NaN  ZTF20abasxmb          NaN
# 13           NaN  ZTF20abbhrrt          NaN
# 14           NaN  ZTF20abeeahl          NaN
# 15           NaN  ZTF20abefbiq          NaN
# 16           NaN  ZTF19adbpulv          NaN
# 17           NaN  ZTF19aacgslb          NaN
# 18           NaN  ZTF19aamhhiz          NaN
# 19           NaN  ZTF19abaeyqw          NaN
# 20           NaN  ZTF18aaoxryq          NaN
# 21           NaN  ZTF19abmprjj          NaN
# 22           NaN  ZTF18aavjcpf          NaN
# 23           NaN  ZTF18abrfchj          NaN
# 24           NaN  ZTF18abtvgxv          NaN
# 25           NaN  ZTF19aacijie          NaN
# 26           NaN  ZTF18acbwtnh          NaN
# 27           NaN  ZTF18acdzzyf          NaN
# 28           NaN  ZTF19aanmzsb          NaN
# 29           NaN  ZTF19abdduix          NaN
# 30           NaN  ZTF19abhcefa          NaN
# 31           NaN  ZTF19abmqasg          NaN
# 32           NaN  ZTF19abqmpti          NaN
# 33           NaN  ZTF19abtulak          NaN
# 34           NaN  ZTF19abyjgal          NaN
# 35           NaN  ZTF19acigkma          NaN
# 36           NaN  ZTF19acihlft          NaN
# 37           NaN  ZTF19acqdato          NaN
# 38           NaN  ZTF20aaivvwa          NaN
# 39           NaN  ZTF20aapdgaw          NaN
# 40           NaN  ZTF20aaurjzv          NaN
# 41           NaN  ZTF20aavgmli          NaN
# 42           NaN  ZTF20aawefgx          NaN
# 43           NaN  ZTF20aayvmyh          NaN
