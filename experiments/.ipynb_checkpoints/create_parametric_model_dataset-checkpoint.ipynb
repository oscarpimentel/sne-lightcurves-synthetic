# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = '../../astro-lightcurves-handler/save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../astro-lightcurves-handler/save)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../astro-lightcurves-handler/save)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

filedir = '../../astro-lightcurves-handler/save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.splcds'
filedir = '../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds'

filedic = get_dict_from_filedir(filedir)
root_folder = filedic['*rootdir*']
cfilename = filedic['*cfilename*']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# > loading: ../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [raw - samples 2,047]
# (*) obs_samples: 65,174 - min_len: 6 - max_dur: 538.8[days] - p50_dur: 52.9[days]
# (g) obs_samples: 28,351 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 38.9[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 36,823 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 50.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 33/2,047 (1.61%)
#    |█████▉  | SNIa - 1,534/2,047 (74.94%)
#    |▍       | SNIbc - 103/2,047 (5.03%)
#    |█▍      | allSNII - 377/2,047 (18.42%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_train - samples 1,636]
# (*) obs_samples: 51,337 - min_len: 6 - max_dur: 443.9[days] - p50_dur: 52.9[days]
# (g) obs_samples: 22,311 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 38.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 29,026 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 50.0[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 26/1,636 (1.59%)
#    |██████  | SNIa - 1,227/1,636 (75.00%)
#    |▍       | SNIbc - 82/1,636 (5.01%)
#    |█▍      | allSNII - 301/1,636 (18.40%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_val - samples 411]
# (*) obs_samples: 13,837 - min_len: 6 - max_dur: 538.8[days] - p50_dur: 53.0[days]
# (g) obs_samples: 6,040 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 39.1[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 7,797 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 51.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 7/411 (1.70%)
#    |█████▉  | SNIa - 307/411 (74.70%)
#    |▍       | SNIbc - 21/411 (5.11%)
#    |█▍      | allSNII - 76/411 (18.49%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,634]
# (*) obs_samples: 50,689 - min_len: 6 - max_dur: 443.9[days] - p50_dur: 52.9[days]
# (g) obs_samples: 22,057 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 38.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 28,632 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 50.0[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 26/1,634 (1.59%)
#    |██████  | SNIa - 1,226/1,634 (75.03%)
#    |▍       | SNIbc - 82/1,634 (5.02%)
#    |█▍      | allSNII - 300/1,634 (18.36%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 410]
# (*) obs_samples: 13,553 - min_len: 5 - max_dur: 538.8[days] - p50_dur: 53.0[days]
# (g) obs_samples: 5,933 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 39.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 7,620 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 51.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 7/410 (1.71%)
#    |█████▉  | SNIa - 306/410 (74.63%)
#    |▍       | SNIbc - 21/410 (5.12%)
#    |█▍      | allSNII - 76/410 (18.54%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# # get error distribution fit

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import ObsErrorConditionalSampler
from synthsne.plots.samplers import plot_obse_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
obse_sampler_bdict = {b:ObsErrorConditionalSampler(lcdataset, set_name, b) for b in band_names}
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1, add_samples=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 13.652067739109985
# 15.17884153552585

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import CurveLengthSampler
from synthsne.plots.samplers import plot_length_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
offset = 5
length_sampler_bdict = {b:CurveLengthSampler(lcdataset, set_name, b, offset) for b in band_names}
plot_length_samplers(length_sampler_bdict, lcdataset, set_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.generators.synthetic_curves import get_syn_sne_generator
from synthsne.plots.lc import plot_synthetic_samples

set_name = 'train'
#method = 'dummy'
#method = 'curve_fit'
method = 'mcmc'

synthetic_samples_per_curve = 32

lcset = lcdataset[set_name]
ignored_lcobj_names = [ # pass to .txt?
    'ZTF18aajkivu',
    'ZTF20aacbwbm',
]
weird_lcobj_names = [
    'ZTF19aaqrime',
    'ZTF19aafljiq',
    'ZTF19aamhhiz',
    'ZTF19abaeyqw',
]
for lcobj_name in ignored_lcobj_names:
#for lcobj_name in weird_lcobj_names:
    #lcobj_name = lc_set.get_random_lcobj_name() # random
    if not lcobj_name in lcset.get_lcobj_names():
        continue
    lcobj = lcset[lcobj_name]
    band_names = lcset.band_names
    class_names = lcset.class_names
    gen_kwargs = {
        #'uses_new_bounds':False,
        'uses_new_bounds':True,
    }
    generator_class = get_syn_sne_generator(method)
    sne_generator = generator_class(lcobj, class_names, band_names, obse_sampler_bdict, length_sampler_bdict, **gen_kwargs)
    new_lcobjs, new_smooth_lcojbs, trace_bdict = sne_generator.sample_curves(synthetic_samples_per_curve)
    plot_kwargs = {
        'trace_bdict':trace_bdict,
        #'save_filedir':f'../save/test_{lcobj_name}.png',
        'save_filedir':None,
    }
    plot_synthetic_samples(lcdataset, set_name, method, lcobj_name, new_lcobjs, new_smooth_lcojbs, **plot_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # generate synth data

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.generators.synthetic_datasets import generate_synthetic_dataset

methods = ['mcmc', 'curve_fit', 'dummy']
#methods = ['mcmc', 'curve_fit']
for method in methods:
    sd_kwargs = {
        'synthetic_samples_per_curve':64,
        'method':method,
        'ignored_lcobj_names':ignored_lcobj_names,
        'save_rootdir':'../save',
    }
    errors = generate_synthetic_dataset(lcdataset, 'train', obse_sampler_bdict, length_sampler_bdict, **sd_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/1634 [?it/s, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abnacvf - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 3/1634 [112.56s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aarphwc - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 6/1634 [141.99s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abpbopt - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 7/1634 [154.00s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaqrime - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 9/1634 [154.09s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aanesgt - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 10/1634 [170.26s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acfwynw - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 11/1634 [153.10s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamrais - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 16/1634 [126.13s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aalbrgu - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 17/1634 [170.78s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaeopgw - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|▏         | 23/1634 [165.07s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aafljiq - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 25/1634 [104.76s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aayprqz - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 43 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 26/1634 [113.90s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abclykm - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 29/1634 [135.27s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aayqait - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 30/1634 [147.78s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aaurfcm - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 31/1634 [174.89s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aanxnkd - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 32/1634 [178.65s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18aaxcxih - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 33/1634 [222.13s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aagzchj - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 34/1634 [216.20s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaumvig - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 36/1634 [233.81s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aawmlfq - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 40/1634 [121.92s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aainjpz - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 41/1634 [178.02s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaphmto - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 45/1634 [169.03s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abrogbl - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 48/1634 [196.02s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aazoqmh - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 50/1634 [157.09s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18ablrljh - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 51/1634 [176.57s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18abwlonm - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 52/1634 [162.39s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aaeujsk - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 53/1634 [199.21s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abidfxd - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 54/1634 [210.72s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aatxryt - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   3%|▎         | 55/1634 [194.10s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF
/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaokist - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▌       | 419/1634 [287.96s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aakoasy - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▌       | 420/1634 [307.50s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aafcgca - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▌       | 421/1634 [309.78s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aakrawk - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▌       | 425/1634 [335.56s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abqxhhr - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▌       | 427/1634 [316.69s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abgqvyr - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▋       | 430/1634 [305.00s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18aaxnkos - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▋       | 431/1634 [314.66s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aapbgty - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  26%|██▋       | 433/1634 [389.34s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aabcnkx - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#  27%|██▋       | 434/1634 [374.11s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18abcyilc - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#  27%|██▋       | 439/1634 [396.72s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acgemzm - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  27%|██▋       | 440/1634 [383.39s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aausxam - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#  27%|██▋       | 441/1634 [393.54s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaqtcmy - ignored: False]

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.plots import plot_obs_obse_scatter

plot_obs_obse_scatter(lcdataset, 'train', 'synth_train')

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import flamingchoripan.cutePlots.colors as cc
import flamingchoripan.cutePlots.plots as cplots

figsize = (12,5)
fig, ax = plt.subplots(1, 1, figsize=figsize)
for ks,set_name in enumerate(['synth_train']):
    lcset = lcdataset.get(set_name)
    lcobj_classes = lcset.get_lcobj_classes()
    to_plot = {'class samples':lcobj_classes}
    title = 'class population distribution\n'
    title += f'survey: {lcset.survey} - set: {set_name} - class samples: {len(lcobj_classes):,}'
    plt_kwargs = {
        'fig':fig,
        'ax':ax,
        'ylabel':'' if ks>0 else None,
        'legend_ncol':len(lcset.band_names),
        'title':title,
        'cmap':cc.colorlist_to_cmap([cc.NICE_COLORS_DICT['nice_gray']]),
        'uses_log_scale':0,
    }
    fig, ax = cplots.plot_hist_labels(to_plot, lcset.class_names, **plt_kwargs)
    
fig.tight_layout()
plt.plot()

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_synthetic_samples

plot_synthetic_samples(lcdataset, 'train', max_samples=1)

# %%
# %load_ext autoreload
# %autoreload 2
from src.umaps import get_fitted_umap, get_transformed_umap

set_name_train = 'train'
set_name_test = 'synth_train'
30
pm_umap_results = get_fitted_umap(lcdataset, set_name_test)
res = get_transformed_umap(lcdataset, pm_umap_results, set_name_train, set_name_test)
pm_args_embd_results_train, pm_args_embd_results_test = res

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_2Dprojections

for c in [None]+lcdataset.raw.class_names:
    kwargs = {
        'target_class':c,
        #'x_mode':'x_pca',
        'x_mode':'x_umap',
        'x_mode':'x_tsne',
    }
    plot_2Dprojections(lcdataset, set_name_train, pm_args_embd_results_train, set_name_test, pm_args_embd_results_test, **kwargs)

# %%
from flamingchoripan.myUtils.files import load_pickle, save_pickle
from src import C_

assert 0
save_filedir = f'{root_folder}/{cfilename}.{C_.EXT_PARAMETRIC_LIGHTCURVE}'
save_pickle(save_filedir, lcdataset)
