# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

kf = '.'
lcset_name = 'train'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe'
methods = [
    'linear-fstw',
    'bspline-fstw',
    #'spm-mle-fstw',
    #'spm-mle-estw',
    'spm-mcmc-fstw',
    'spm-mcmc-estw',
    ]

# %%
for method in methods:
    any_incorrects_fittings = sms.get_any_incorrects_fittings(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - any_incorrects_fittings={len(any_incorrects_fittings)} #')
    
for method in methods:
    all_incorrects_fittings = sms.get_all_incorrects_fittings(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - all_incorrects_fittings={len(all_incorrects_fittings)} #')
# Out:
# method=linear-fstw - any_incorrects_fittings=518 #
# method=bspline-fstw - any_incorrects_fittings=1445 #
# method=spm-mcmc-fstw - any_incorrects_fittings=615 #
# method=spm-mcmc-estw - any_incorrects_fittings=604 #
# method=linear-fstw - all_incorrects_fittings=3 #
# method=bspline-fstw - all_incorrects_fittings=397 #
# method=spm-mcmc-fstw - all_incorrects_fittings=16 #
# method=spm-mcmc-estw - all_incorrects_fittings=16 #

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    xe_ptimes = sms.get_perf_times(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(f'method={method} - xe_ptimes={xe_ptimes}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# method=linear-fstw - xe_ptimes=1.610±1.623
# method=bspline-fstw - xe_ptimes=1.313±1.078
# method=spm-mcmc-fstw - xe_ptimes=119.357±70.988
# method=spm-mcmc-estw - xe_ptimes=97.838±50.918

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms
from flamingchoripan.latex.latex_tables import LatexTable

info_df = sms.get_info_dict(f'../save/ssne', methods, cfilename, kf, lcset_name)
latex_kwargs = {
    'caption':f'set={kf}@train',
    'label':'???',
    'custom_tabular_align':'lc|'+'c'*sum([m.split('-')[-1]=='fstw' for m in methods])+'|'+'c'*sum([m.split('-')[-1]=='estw' for m in methods]), 
}
latex_table = LatexTable(info_df, **latex_kwargs)
print(latex_table)
info_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{set=.@train}
# \label{???}\vspace{.1cm}
# \begin{tabular}{lc|ccc|c}
# \hline
# metric & band & linear-fstw & bspline-fstw & spm-mcmc-fstw & spm-mcmc-estw \srule\\\hline\hline
# trace-time [segs] & . & 1.529$\pm$1.578 & 1.182$\pm$1.029 & 113.725$\pm$70.676 & 93.140$\pm$51.168  \srule\\
# fit-log-error & g & 1.659$\pm$.527 & 4.153$\pm$2.162 & 3.393$\pm$.849 & 3.393$\pm$.848  \srule\\
# fits-success [\%] & g & 93.003 & 79.075 & 91.972 & 92.006  \srule\\
# fit-log-error & r & 1.776$\pm$.451 & 4.913$\pm$1.983 & 3.718$\pm$.824 & 3.719$\pm$.829  \srule\\
# fits-success [\%] & r & 98.040 & 88.608 & 97.181 & 97.335  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                  linear-fstw bspline-fstw   spm-mcmc-fstw  \
# metric=trace-time [segs]~band=.  1.529±1.578  1.182±1.029  113.725±70.676
# metric=fit-log-error~band=g       1.659±.527  4.153±2.162      3.393±.849
# metric=fits-success [%]~band=g     93.003266    79.074802       91.971807
# metric=fit-log-error~band=r       1.776±.451  4.913±1.983      3.718±.824
# metric=fits-success [%]~band=r     98.040227    88.607745       97.180677
#
#                                  spm-mcmc-estw
# metric=trace-time [segs]~band=.  93.140±51.168
# metric=fit-log-error~band=g         3.393±.848
# metric=fits-success [%]~band=g       92.006189
# metric=fit-log-error~band=r         3.719±.829
# metric=fits-success [%]~band=r       97.335396

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    rank_bdict = sms.get_ranks(f'../save/ssne/{method}/{cfilename}', kf, lcset_name)
    print(method)
    for b in rank_bdict.keys():
        print(rank_bdict[b])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# linear-fstw
# band=g:
# [1#] 1@ZTF18aasdted=33.6901
# [2#] 4@ZTF20aamuqwn=33.5178
# [3#] 3@ZTF20aamuqwn=33.0312
# [4#] 3@ZTF18aasdted=32.1134
# [5#] 2@ZTF18aasdted=29.1145
# [6#] 0@ZTF20aamuqwn=28.4677
# [7#] 2@ZTF20aaaxacu=18.9981
# [8#] 1@ZTF20aaomtwl=18.3786
# [9#] 3@ZTF20aatzhhl=18.0501
# [10#] 2@ZTF20aatzhhl=17.8481
# band=r:
# [1#] 2@ZTF18aasdted=33.9103
# [2#] 1@ZTF18aasdted=31.7609
# [3#] 3@ZTF18aasdted=31.4861
# [4#] 4@ZTF20aamuqwn=21.1445
# [5#] 3@ZTF19aatlmbo=19.7282
# [6#] 2@ZTF19aatlmbo=18.8890
# [7#] 0@ZTF20aamuqwn=18.7763
# [8#] 3@ZTF20aamuqwn=18.5197
# [9#] 1@ZTF19aatlmbo=17.9045
# [10#] 1@ZTF18aaqkcso=16.1258
# bspline-fstw
# band=g:
# [1#] 4@ZTF19aawmkja=9,891.6976
# [2#] 1@ZTF20abefdvd=9,829.1270
# [3#] 2@ZTF20abgbxfm=9,817.6273
# [4#] 0@ZTF19abpzuzd=9,752.2307
# [5#] 4@ZTF20abefdvd=9,727.5682
# [6#] 0@ZTF19aawmkja=9,713.0802
# [7#] 2@ZTF20abefdvd=9,684.8833
# [8#] 2@ZTF19acbpqvc=9,678.3447
# [9#] 3@ZTF19aaileug=9,641.0550
# [10#] 4@ZTF18abuhzfc=9,633.3316
# band=r:
# [1#] 4@ZTF19abclykm=9,996.6090
# [2#] 2@ZTF20aavnnkm=9,978.4055
# [3#] 4@ZTF19abjbtbm=9,977.7724
# [4#] 2@ZTF19aaomkvl=9,968.0323
# [5#] 3@ZTF19abuhlxk=9,956.8805
# [6#] 1@ZTF20aabqiti=9,947.5885
# [7#] 1@ZTF20aavnnkm=9,946.6314
# [8#] 4@ZTF20aanadlu=9,912.9542
# [9#] 2@ZTF19abclykm=9,867.5090
# [10#] 3@ZTF18abdpvnd=9,804.5469
# spm-mcmc-fstw
# band=g:
# [1#] 2@ZTF19adcecwu=1,394.7840
# [2#] 1@ZTF19adcecwu=1,394.4599
# [3#] 0@ZTF19adcecwu=1,380.1503
# [4#] 1@ZTF20aaszzez=1,215.8773
# [5#] 2@ZTF20aaszzez=1,213.5123
# [6#] 4@ZTF19aadnxnl=1,127.6867
# [7#] 0@ZTF19aadnxnl=1,127.5797
# [8#] 3@ZTF19aadnxnl=1,127.3242
# [9#] 0@ZTF20aaszzez=1,092.8811
# [10#] 2@ZTF19abcekty=1,052.8045
# band=r:
# [1#] 0@ZTF18adbckhw=3,933.5433
# [2#] 1@ZTF18adbckhw=3,932.4108
# [3#] 2@ZTF18adbckhw=3,931.6196
# [4#] 3@ZTF18aasdted=1,618.9482
# [5#] 1@ZTF18aasdted=1,618.7116
# [6#] 2@ZTF18aasdted=1,618.4909
# [7#] 4@ZTF18acbwtng=1,262.1349
# [8#] 3@ZTF18acbwtng=1,260.5012
# [9#] 0@ZTF18acbwtng=1,222.6587
# [10#] 1@ZTF18acrdlrp=1,084.0098
# spm-mcmc-estw
# band=g:
# [1#] 2@ZTF19adcecwu=1,395.6949
# [2#] 1@ZTF19adcecwu=1,394.8135
# [3#] 0@ZTF19adcecwu=1,379.9243
# [4#] 0@ZTF20aaszzez=1,216.1030
# [5#] 0@ZTF19aadnxnl=1,129.2571
# [6#] 3@ZTF19aadnxnl=1,127.6229
# [7#] 4@ZTF19aadnxnl=1,126.9530
# [8#] 2@ZTF20aaszzez=1,119.7969
# [9#] 1@ZTF20aaszzez=1,110.3049
# [10#] 2@ZTF19abcekty=1,051.8255
# band=r:
# [1#] 2@ZTF18adbckhw=3,938.4318
# [2#] 1@ZTF18adbckhw=3,930.7929
# [3#] 0@ZTF18adbckhw=3,928.2677
# [4#] 2@ZTF18aasdted=1,620.1394
# [5#] 1@ZTF18aasdted=1,619.1233
# [6#] 3@ZTF18aasdted=1,618.2641
# [7#] 4@ZTF18acbwtng=1,253.7915
# [8#] 0@ZTF18acbwtng=1,247.9496
# [9#] 3@ZTF18acbwtng=1,224.8032
# [10#] 4@ZTF18acrdlrp=1,084.6473

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms
from flamingchoripan.files import load_pickle
from flamingchoripan.dataframes import DFBuilder
from flamingchoripan.latex.latex_tables import LatexTable

kf = '0'
lcset_name = 'train'
cfilename = f'survey=alerceZTFv7.1~bands=gr~mode=onlySNe'
filedir = f'../save/mcmc_priors/{cfilename}/{kf}@{lcset_name}/mcmc_priors.d'
priors_d = load_pickle(filedir)
info_df = DFBuilder()
spms = ['A','t0','gamma','f','trise','tfall']
for b in ['g', 'r']:
    for spm_p in spms:
        d = {}
        for c in ['SLSN', 'SNIa', 'SNIbc', 'allSNII']:
            d[c] = priors_d[b][c][spm_p]
    
        info_df.append(f'SPM var={spm_p}~band={b}', d)
    
info_df = info_df.get_df()
latex_kwargs = {
    'caption':f'set={kf}@train',
    'label':'???',
    'hline_k':len(spms)-1,
    }
latex_table = LatexTable(info_df, **latex_kwargs)
print(latex_table)
info_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{set=0@train}
# \label{???}\vspace{.1cm}
# \begin{tabular}{lc|cccc}
# \hline
# SPM var & band & SLSN & SNIa & SNIbc & allSNII \srule\\\hline\hline
# A & g & Gamma$\left(3.003, 11.478, 0.000\right)$ & Gamma$\left(1.554, 3.481, 0.000\right)$ & Gamma$\left(1.162, 2.548, 0.000\right)$ & Gamma$\left(1.059, 2.313, 0.000\right)$  \srule\\
# t0 & g & Normal$\left(22.499, 15.440\right)$ & Normal$\left(4.690, 5.162\right)$ & Normal$\left(5.609, 7.492\right)$ & Normal$\left(2.039, 13.702\right)$  \srule\\
# gamma & g & Gamma$\left(1.886, 0.028, 1.000\right)$ & Gamma$\left(4.174, 0.168, 1.000\right)$ & Gamma$\left(2.404, 0.105, 1.000\right)$ & Gamma$\left(1.718, 0.038, 1.000\right)$  \srule\\
# f & g & Unif$\left(0.000, 0.990\right)$ & Unif$\left(0.000, 0.990\right)$ & Unif$\left(0.000, 0.990\right)$ & Unif$\left(0.000, 0.990\right)$  \srule\\
# trise & g & Gamma$\left(1.774, 0.128, 1.000\right)$ & Gamma$\left(2.819, 1.074, 1.000\right)$ & Gamma$\left(1.037, 0.266, 1.000\right)$ & Gamma$\left(0.629, 0.085, 1.000\right)$  \srule\\
# tfall & g & Gamma$\left(1.506, 0.025, 1.000\right)$ & Gamma$\left(1.658, 0.034, 1.000\right)$ & Gamma$\left(2.387, 0.041, 1.000\right)$ & Gamma$\left(1.703, 0.029, 1.000\right)$  \srule\\
# \hline
# A & r & Gamma$\left(3.890, 15.004, 0.000\right)$ & Gamma$\left(1.634, 3.705, 0.000\right)$ & Gamma$\left(1.166, 2.038, 0.000\right)$ & Gamma$\left(1.188, 2.510, 0.000\right)$  \srule\\
# t0 & r & Normal$\left(28.237, 19.898\right)$ & Normal$\left(5.690, 6.014\right)$ & Normal$\left(5.641, 5.662\right)$ & Normal$\left(5.845, 22.766\right)$  \srule\\
# gamma & r & Gamma$\left(2.473, 0.036, 1.000\right)$ & Gamma$\left(1.515, 0.060, 1.000\right)$ & Gamma$\left(2.963, 0.098, 1.000\right)$ & Gamma$\left(2.697, 0.039, 1.000\right)$  \srule\\
# f & r & Unif$\left(0.000, 0.990\right)$ & Unif$\left(0.000, 0.990\right)$ & Unif$\left(0.011, 0.990\right)$ & Unif$\left(0.000, 0.990\right)$  \srule\\
# trise & r & Gamma$\left(2.257, 0.160, 1.000\right)$ & Gamma$\left(2.525, 0.838, 1.000\right)$ & Gamma$\left(1.866, 0.582, 1.000\right)$ & Gamma$\left(0.613, 0.050, 1.000\right)$  \srule\\
# tfall & r & Gamma$\left(1.591, 0.029, 1.000\right)$ & Gamma$\left(1.959, 0.048, 1.000\right)$ & Gamma$\left(2.179, 0.046, 1.000\right)$ & Gamma$\left(1.273, 0.022, 1.000\right)$  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                                           SLSN  \
# SPM var=A~band=g      Gamma$\left(3.003, 11.478, 0.000\right)$
# SPM var=t0~band=g          Normal$\left(22.499, 15.440\right)$
# SPM var=gamma~band=g   Gamma$\left(1.886, 0.028, 1.000\right)$
# SPM var=f~band=g               Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=g   Gamma$\left(1.774, 0.128, 1.000\right)$
# SPM var=tfall~band=g   Gamma$\left(1.506, 0.025, 1.000\right)$
# SPM var=A~band=r      Gamma$\left(3.890, 15.004, 0.000\right)$
# SPM var=t0~band=r          Normal$\left(28.237, 19.898\right)$
# SPM var=gamma~band=r   Gamma$\left(2.473, 0.036, 1.000\right)$
# SPM var=f~band=r               Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=r   Gamma$\left(2.257, 0.160, 1.000\right)$
# SPM var=tfall~band=r   Gamma$\left(1.591, 0.029, 1.000\right)$
#
#                                                          SNIa  \
# SPM var=A~band=g      Gamma$\left(1.554, 3.481, 0.000\right)$
# SPM var=t0~band=g           Normal$\left(4.690, 5.162\right)$
# SPM var=gamma~band=g  Gamma$\left(4.174, 0.168, 1.000\right)$
# SPM var=f~band=g              Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=g  Gamma$\left(2.819, 1.074, 1.000\right)$
# SPM var=tfall~band=g  Gamma$\left(1.658, 0.034, 1.000\right)$
# SPM var=A~band=r      Gamma$\left(1.634, 3.705, 0.000\right)$
# SPM var=t0~band=r           Normal$\left(5.690, 6.014\right)$
# SPM var=gamma~band=r  Gamma$\left(1.515, 0.060, 1.000\right)$
# SPM var=f~band=r              Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=r  Gamma$\left(2.525, 0.838, 1.000\right)$
# SPM var=tfall~band=r  Gamma$\left(1.959, 0.048, 1.000\right)$
#
#                                                         SNIbc  \
# SPM var=A~band=g      Gamma$\left(1.162, 2.548, 0.000\right)$
# SPM var=t0~band=g           Normal$\left(5.609, 7.492\right)$
# SPM var=gamma~band=g  Gamma$\left(2.404, 0.105, 1.000\right)$
# SPM var=f~band=g              Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=g  Gamma$\left(1.037, 0.266, 1.000\right)$
# SPM var=tfall~band=g  Gamma$\left(2.387, 0.041, 1.000\right)$
# SPM var=A~band=r      Gamma$\left(1.166, 2.038, 0.000\right)$
# SPM var=t0~band=r           Normal$\left(5.641, 5.662\right)$
# SPM var=gamma~band=r  Gamma$\left(2.963, 0.098, 1.000\right)$
# SPM var=f~band=r              Unif$\left(0.011, 0.990\right)$
# SPM var=trise~band=r  Gamma$\left(1.866, 0.582, 1.000\right)$
# SPM var=tfall~band=r  Gamma$\left(2.179, 0.046, 1.000\right)$
#
#                                                       allSNII
# SPM var=A~band=g      Gamma$\left(1.059, 2.313, 0.000\right)$
# SPM var=t0~band=g          Normal$\left(2.039, 13.702\right)$
# SPM var=gamma~band=g  Gamma$\left(1.718, 0.038, 1.000\right)$
# SPM var=f~band=g              Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=g  Gamma$\left(0.629, 0.085, 1.000\right)$
# SPM var=tfall~band=g  Gamma$\left(1.703, 0.029, 1.000\right)$
# SPM var=A~band=r      Gamma$\left(1.188, 2.510, 0.000\right)$
# SPM var=t0~band=r          Normal$\left(5.845, 22.766\right)$
# SPM var=gamma~band=r  Gamma$\left(2.697, 0.039, 1.000\right)$
# SPM var=f~band=r              Unif$\left(0.000, 0.990\right)$
# SPM var=trise~band=r  Gamma$\left(0.613, 0.050, 1.000\right)$
# SPM var=tfall~band=r  Gamma$\left(1.273, 0.022, 1.000\right)$
