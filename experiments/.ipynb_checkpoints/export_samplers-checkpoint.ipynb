# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from synthsne import C_

root_folder = '../../surveys-save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 6.333[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 6.333[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from synthsne import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

filedir = '../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds'

filedict = get_dict_from_filedir(filedir)
root_folder = filedict['*rootdir*']
cfilename = filedict['*cfilename*']
survey = filedict['survey']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# > loading: ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [outliers - samples 17]
# (*) obs_samples: 774 - min_len: 11 - max_dur: 408.0[days] - dur(p50): 130.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 365 - min_len: 0 - max_dur: 408.0[days] - dur(p50): 133.8[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 409 - min_len: 6 - max_dur: 387.9[days] - dur(p50): 126.7[days] - cadence(p50): 3.0[days]
#    |▉       | SLSN - 2/17 (11.76%)
#    |▍       | SNIa - 1/17 (5.88%)
#    |█▉      | SNIbc - 4/17 (23.53%)
#    |████▋   | allSNII - 10/17 (58.82%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw - samples 1,981]
# (*) obs_samples: 54,200 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 23,911 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 39.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 30,289 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 50.8[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 29/1,981 (1.46%)
#    |██████  | SNIa - 1,500/1,981 (75.72%)
#    |▍       | SNIbc - 96/1,981 (4.85%)
#    |█▍      | allSNII - 356/1,981 (17.97%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,266]
# (*) obs_samples: 34,049 - min_len: 4 - max_dur: 538.8[days] - dur(p50): 51.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 15,033 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 38.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 19,016 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 49.9[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 18/1,266 (1.42%)
#    |██████  | SNIa - 960/1,266 (75.83%)
#    |▍       | SNIbc - 61/1,266 (4.82%)
#    |█▍      | allSNII - 227/1,266 (17.93%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 315]
# (*) obs_samples: 8,522 - min_len: 6 - max_dur: 444.7[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 3,747 - min_len: 0 - max_dur: 421.9[days] - dur(p50): 39.5[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 4,775 - min_len: 0 - max_dur: 441.7[days] - dur(p50): 50.9[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 4/315 (1.27%)
#    |██████  | SNIa - 240/315 (76.19%)
#    |▍       | SNIbc - 15/315 (4.76%)
#    |█▍      | allSNII - 56/315 (17.78%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [test - samples 400]
# (*) obs_samples: 11,419 - min_len: 5 - max_dur: 398.9[days] - dur(p50): 55.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 5,050 - min_len: 0 - max_dur: 396.9[days] - dur(p50): 39.4[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 6,369 - min_len: 0 - max_dur: 398.9[days] - dur(p50): 53.8[days] - cadence(p50): 3.0[days]
#    |▏       | SLSN - 7/400 (1.75%)
#    |██████  | SNIa - 300/400 (75.00%)
#    |▍       | SNIbc - 20/400 (5.00%)
#    |█▍      | allSNII - 73/400 (18.25%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train+val - samples 1,581]
# (*) obs_samples: 42,571 - min_len: 4 - max_dur: 538.8[days] - dur(p50): 51.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 18,780 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 38.9[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 23,791 - min_len: 0 - max_dur: 538.7[days] - dur(p50): 49.9[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 22/1,581 (1.39%)
#    |██████  | SNIa - 1,200/1,581 (75.90%)
#    |▍       | SNIbc - 76/1,581 (4.81%)
#    |█▍      | allSNII - 283/1,581 (17.90%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import ObsErrorConditionalSampler
from synthsne.plots.samplers import plot_obse_samplers

set_name = 'train+val'
#set_name = 'test'
band_names = lcdataset[set_name].band_names
obse_sampler_bdict = {b:ObsErrorConditionalSampler(lcdataset, set_name, b) for b in band_names}
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1, add_samples=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 13.104055083861313
# 14.092426200130193

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import CurveLengthSampler
from synthsne.plots.samplers import plot_length_samplers

band_names = lcdataset[set_name].band_names
offset = 5
length_sampler_bdict = {b:CurveLengthSampler(lcdataset, set_name, b, offset) for b in band_names}
plot_length_samplers(length_sampler_bdict, lcdataset, set_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from flamingchoripan.files import load_pickle, save_pickle
from synthsne import C_

to_save = {
    'obse_sampler_bdict':obse_sampler_bdict,
    'length_sampler_bdict':length_sampler_bdict,
}
save_filedir = f'../save/{survey}/{cfilename}/{set_name}/samplers.{C_.EXT_SAMPLER}'
save_pickle(save_filedir, to_save)
# Out:
# > saving: ../save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe/train+val/samplers.smplr
