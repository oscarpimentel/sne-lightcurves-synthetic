# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from synthsne import C_

root_folder = '../save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SAMPLER)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../save)
# (0) - ../save/alerceZTFv7.1/survey=alerceZTFv7.1°bands=gr°mode=onlySNe/train/samplers.smplr - 6.500[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../save)
# (0) - ../save/alerceZTFv7.1/survey=alerceZTFv7.1°bands=gr°mode=onlySNe/train/samplers.smplr - 6.500[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

lcset_name = 'train'
rootdir = f'../save/alerceZTFv7.1/survey=alerceZTFv7.1°bands=gr°mode=onlySNe/{lcset_name}'
methods = ['linear-fstw', 'bspline-fstw', 'spm-mle-fstw', 'spm-mle-estw']
methods = ['linear-fstw', 'bspline-fstw', 'spm-mle-fstw', 'spm-mle-estw', 'spm-mcmc-fstw', 'spm-mcmc-estw']
for method in methods:
    incorrects_fittings = sms.get_all_incorrects_fittings(rootdir, method)
    print(f'{method} ({len(incorrects_fittings)}): {incorrects_fittings}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# linear-fstw (1): ['ZTF18acbwtnh']
# bspline-fstw (92): ['ZTF20aauwjmw', 'ZTF18acqqyah', 'ZTF19aakozyp', 'ZTF19aarnqzw', 'ZTF19abdoznh', 'ZTF20aazgtmp', 'ZTF20aajcdad', 'ZTF19acrdqej', 'ZTF19abecaca', 'ZTF19aadnxat', 'ZTF18abzbkby', 'ZTF20aayxldg', 'ZTF20aayknlo', 'ZTF20aaomtwl', 'ZTF20abbplei', 'ZTF20abawgdl', 'ZTF19abwztsb', 'ZTF18adaslwa', 'ZTF20aaqshoz', 'ZTF19abdzehg', 'ZTF18abuhyjv', 'ZTF19aagmsrr', 'ZTF19aaksrlb', 'ZTF18abfhryc', 'ZTF19aaomkvl', 'ZTF18aasdted', 'ZTF19abcttsc', 'ZTF19aathcvn', 'ZTF20aauowam', 'ZTF19abxjimu', 'ZTF20aakyoez', 'ZTF19aacgslb', 'ZTF20abbhyxu', 'ZTF18aczdetm', 'ZTF19aaupkrl', 'ZTF19aavhxby', 'ZTF19aabmybj', 'ZTF19aadgimr', 'ZTF19aayfaum', 'ZTF20abchhuw', 'ZTF18acdwazf', 'ZTF20aaghlkv', 'ZTF19abqwtfu', 'ZTF18acusbyf', 'ZTF18abcrxoj', 'ZTF18aaumeys', 'ZTF19abqysic', 'ZTF20aavzffg', 'ZTF19aaujzqh', 'ZTF18aczeesl', 'ZTF18acsovsw', 'ZTF20aaaxacu', 'ZTF18acwwonp', 'ZTF20aafrihv', 'ZTF18abgmcmv', 'ZTF18abwkrbl', 'ZTF20aazymxi', 'ZTF19abvhduf', 'ZTF20aavnnkm', 'ZTF19aamhhae', 'ZTF19aatgwhs', 'ZTF19aanhgqg', 'ZTF20aatzhhl', 'ZTF19aaycomi', 'ZTF18acbwtnh', 'ZTF20aanadlu', 'ZTF20aarbget', 'ZTF19aapfmki', 'ZTF18acbwaxk', 'ZTF19abuhlxk', 'ZTF20aautzif', 'ZTF19aaxfcpq', 'ZTF19aawfcgp', 'ZTF20aayprqz', 'ZTF19aabyheu', 'ZTF19abyjjxp', 'ZTF18accwjiu', 'ZTF19aaknvuh', 'ZTF20aamuqwn', 'ZTF20aamdhut', 'ZTF19abdrwsz', 'ZTF19acazaug', 'ZTF20abchbds', 'ZTF18aaiykoz', 'ZTF19aatlmbo', 'ZTF20aahfobk', 'ZTF19acojuzv', 'ZTF19acrbyzj', 'ZTF19aamhqej', 'ZTF18aaybfsd', 'ZTF20aavhire', 'ZTF18aaqkcso']
# spm-mle-fstw (1): ['ZTF18acbwtnh']
# spm-mle-estw (1): ['ZTF18acbwtnh']
# spm-mcmc-fstw (2): ['ZTF19aavyafo', 'ZTF18acbwtnh']
# spm-mcmc-estw (2): ['ZTF19aavyafo', 'ZTF18acbwtnh']

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    xe_ptimes = sms.get_perf_times(rootdir, method)
    print(f'{method} ({len(xe_ptimes)}): {xe_ptimes}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# linear-fstw (1162): .65±.28
# bspline-fstw (1071): .57±.22
# spm-mle-fstw (1162): 9.38±4.65
# spm-mle-estw (1162): 9.61±4.68
# spm-mcmc-fstw (1161): 92.80±18.45
# spm-mcmc-estw (1161): 93.23±18.80

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms
from flamingchoripan.latex.latex_tables import LatexTable

info_df = sms.get_info_dict(rootdir, methods)
latex_kwargs = {
    'caption':'$x_j$',
    'label':'???',
    #'bold_criteriums':{c:'max' if ('%' in c or 'fits-n' in c) else 'min' for c in info_df.columns},
    'custom_tabular_align':'l|c|ccc|ccc|ccc',
}
latex_table = LatexTable(info_df, **latex_kwargs)
print(latex_table)
info_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \def\srule{\rule{0pt}{2ex}\rule[-1ex]{0pt}{0ex}}
# \begin{table*}
# \centering
# \caption{$x_j$}
# \label{???}\vspace{.1cm}
# \begin{tabular}{l|c|ccc|ccc|ccc}
# \hline
# method & trace-time [segs] & mb-fit-log-error & mb-fits-n & mb-fits [\%] & g-fit-log-error & g-fits-n & g-fits [\%] & r-fit-log-error & r-fits-n & r-fits [\%] \srule\\\hline\hline
# bspline-fstw & .54$\pm$.23 & 4.54$\pm$2.22 & 61,835 & 83.08 & 4.08$\pm$2.30 & 29,159 & 78.35 & 4.94$\pm$2.06 & 32,676 & 87.80  \srule\\
# linear-fstw & .65$\pm$.28 & 1.31$\pm$.49 & 70,978 & 95.36 & 1.24$\pm$.53 & 34,586 & 92.93 & 1.38$\pm$.44 & 36,392 & 97.79  \srule\\
# spm-mle-fstw & 9.37$\pm$4.65 & 3.03$\pm$1.36 & 70,990 & 95.38 & 2.67$\pm$1.39 & 34,587 & 92.94 & 3.38$\pm$1.24 & 36,403 & 97.82  \srule\\
# spm-mle-estw & 9.61$\pm$4.68 & 3.03$\pm$1.36 & 70,994 & 95.38 & 2.67$\pm$1.39 & 34,592 & 92.95 & 3.37$\pm$1.25 & 36,402 & 97.81  \srule\\
# spm-mcmc-fstw & 92.64$\pm$18.83 & 3.50$\pm$.88 & 70,464 & 94.67 & 3.31$\pm$.87 & 34,336 & 92.26 & 3.68$\pm$.86 & 36,128 & 97.08  \srule\\
# spm-mcmc-estw & 93.07$\pm$19.18 & 3.50$\pm$.89 & 70,592 & 94.84 & 3.31$\pm$.87 & 34,304 & 92.18 & 3.68$\pm$.87 & 36,288 & 97.51  \srule\\
# \hline
# \end{tabular}
# \end{table*}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                      trace-time [segs] mb-fit-log-error  mb-fits-n  \
# method=bspline-fstw            .54±.23        4.54±2.22      61835
# method=linear-fstw             .65±.28         1.31±.49      70978
# method=spm-mle-fstw          9.37±4.65        3.03±1.36      70990
# method=spm-mle-estw          9.61±4.68        3.03±1.36      70994
# method=spm-mcmc-fstw       92.64±18.83         3.50±.88      70464
# method=spm-mcmc-estw       93.07±19.18         3.50±.89      70592
#
#                       mb-fits [%] g-fit-log-error  g-fits-n  g-fits [%]  \
# method=bspline-fstw     83.075828       4.08±2.30     29159   78.350709
# method=linear-fstw      95.359523        1.24±.53     34586   92.933147
# method=spm-mle-fstw     95.375645       2.67±1.39     34587   92.935834
# method=spm-mle-estw     95.381019       2.67±1.39     34592   92.949269
# method=spm-mcmc-fstw    94.668960        3.31±.87     34336   92.261393
# method=spm-mcmc-estw    94.840929        3.31±.87     34304   92.175408
#
#                      r-fit-log-error  r-fits-n  r-fits [%]
# method=bspline-fstw        4.94±2.06     32676   87.800946
# method=linear-fstw          1.38±.44     36392   97.785899
# method=spm-mle-fstw        3.38±1.24     36403   97.815456
# method=spm-mle-estw        3.37±1.25     36402   97.812769
# method=spm-mcmc-fstw        3.68±.86     36128   97.076526
# method=spm-mcmc-estw        3.68±.87     36288   97.506449

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne import synth_method_statistics as sms

for method in methods:
    rank, rank_bdict, band_names = sms.get_ranks(rootdir, method)
    print(method)
    print(rank)
    for b in band_names:
        print(rank_bdict[b])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
