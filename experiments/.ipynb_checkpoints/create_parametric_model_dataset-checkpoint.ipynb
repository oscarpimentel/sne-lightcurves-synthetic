# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from lchandler import C_

root_folder = '../../astro-lightcurves-handler/save'
filedirs = search_for_filedirs(root_folder, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../astro-lightcurves-handler/save)
# (0) - ../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds - 5.163[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../astro-lightcurves-handler/save)
# (0) - ../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds - 5.163[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

filedir = '../../astro-lightcurves-handler/save/alerceZTFv5.1/survey-alerceZTFv5.1_bands-gr_mode-onlySNe_kfid-0.splcds'
filedir = '../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds'

filedic = get_dict_from_filedir(filedir)
root_folder = filedic['*rootdir*']
cfilename = filedic['*cfilename*']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# > loading: ../../astro-lightcurves-handler/save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_kfid-0.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [raw - samples 2,047]
# (*) obs_samples: 65,174 - min_len: 6 - max_dur: 538.8[days] - p50_dur: 52.9[days]
# (g) obs_samples: 28,351 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 38.9[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 36,823 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 50.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 33/2,047 (1.61%)
#    |█████▉  | SNIa - 1,534/2,047 (74.94%)
#    |▍       | SNIbc - 103/2,047 (5.03%)
#    |█▍      | allSNII - 377/2,047 (18.42%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_train - samples 1,636]
# (*) obs_samples: 51,337 - min_len: 6 - max_dur: 443.9[days] - p50_dur: 52.9[days]
# (g) obs_samples: 22,311 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 38.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 29,026 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 50.0[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 26/1,636 (1.59%)
#    |██████  | SNIa - 1,227/1,636 (75.00%)
#    |▍       | SNIbc - 82/1,636 (5.01%)
#    |█▍      | allSNII - 301/1,636 (18.40%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw_val - samples 411]
# (*) obs_samples: 13,837 - min_len: 6 - max_dur: 538.8[days] - p50_dur: 53.0[days]
# (g) obs_samples: 6,040 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 39.1[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 7,797 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 51.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 7/411 (1.70%)
#    |█████▉  | SNIa - 307/411 (74.70%)
#    |▍       | SNIbc - 21/411 (5.11%)
#    |█▍      | allSNII - 76/411 (18.49%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,634]
# (*) obs_samples: 50,689 - min_len: 6 - max_dur: 443.9[days] - p50_dur: 52.9[days]
# (g) obs_samples: 22,057 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 38.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 28,632 - min_len: 0 - max_dur: 443.9[days] - p50_dur: 50.0[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 26/1,634 (1.59%)
#    |██████  | SNIa - 1,226/1,634 (75.03%)
#    |▍       | SNIbc - 82/1,634 (5.02%)
#    |█▍      | allSNII - 300/1,634 (18.36%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 410]
# (*) obs_samples: 13,553 - min_len: 5 - max_dur: 538.8[days] - p50_dur: 53.0[days]
# (g) obs_samples: 5,933 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 39.0[days] - p50_cadence: 3.0[days]
# (r) obs_samples: 7,620 - min_len: 0 - max_dur: 538.8[days] - p50_dur: 51.9[days] - p50_cadence: 3.0[days]
#    |▏       | SLSN - 7/410 (1.71%)
#    |█████▉  | SNIa - 306/410 (74.63%)
#    |▍       | SNIbc - 21/410 (5.12%)
#    |█▍      | allSNII - 76/410 (18.54%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# # get error distribution fit

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import ObsErrorConditionalSampler
from synthsne.plots.samplers import plot_obse_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
obse_sampler_bdict = {b:ObsErrorConditionalSampler(lcdataset, set_name, b) for b in band_names}
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=1, add_samples=1)
plot_obse_samplers(lcdataset, set_name, obse_sampler_bdict, original_space=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 13.652067739109985
# 15.17884153552585

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.distr_fittings import CurveLengthSampler
from synthsne.plots.samplers import plot_length_samplers

set_name = 'train'
band_names = lcdataset[set_name].band_names
offset = 0
length_sampler_bdict = {b:CurveLengthSampler(lcdataset, set_name, b, offset) for b in band_names}
plot_length_samplers(length_sampler_bdict, lcdataset, set_name)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.generators.synthetic_curves import get_syn_sne_generator
from synthsne.plots.lc import plot_synthetic_samples

set_name = 'train'
#method = 'dummy'
method = 'curve_fit'
#method = 'mcmc'

synthetic_samples_per_curve = 32

lcset = lcdataset[set_name]
ignored_lcobj_names = [ # pass to .txt?
    'ZTF18aajkivu',
    'ZTF20aacbwbm',
]
weird_lcobj_names = [
    'ZTF19aaqrime',
    'ZTF19aafljiq',
    'ZTF19aamhhiz',
    'ZTF19abaeyqw',
]
for lcobj_name in weird_lcobj_names:
    #lcobj_name = lc_set.get_random_lcobj_name() # random
    if not lcobj_name in lcset.get_lcobj_names():
        continue
    lcobj = lcset[lcobj_name]
    band_names = lcset.band_names
    class_names = lcset.class_names
    gen_kwargs = {
        #'uses_new_bounds':False,
        'uses_new_bounds':True,
    }
    generator_class = get_syn_sne_generator(method)
    sne_generator = generator_class(lcobj, class_names, band_names, obse_sampler_bdict, length_sampler_bdict, **gen_kwargs)
    new_lcobjs, new_smooth_lcojbs, trace_bdict = sne_generator.sample_curves(synthetic_samples_per_curve)
    plot_kwargs = {
        'trace_bdict':trace_bdict,
        #'save_filedir':f'../save/test_{lcobj_name}.png',
        'save_filedir':None,
    }
    plot_synthetic_samples(lcdataset, set_name, method, lcobj_name, new_lcobjs, new_smooth_lcojbs, **plot_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# # generate synth data

# %%
# %load_ext autoreload
# %autoreload 2
from synthsne.generators.synthetic_datasets import generate_synthetic_dataset

methods = ['mcmc', 'curve_fit']
for method in methods:
    sd_kwargs = {
        'synthetic_samples_per_curve':64,
        'method':method,
        'ignored_lcobj_names':ignored_lcobj_names,
        'save_rootdir':'../save',
    }
    errors = generate_synthetic_dataset(lcdataset, 'train', obse_sampler_bdict, length_sampler_bdict, **sd_kwargs)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   0%|          | 0/1634 [?it/s, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abnacvf - ignored: False]
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '31332' (I am process '31344')
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 80 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 107 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 2/1634 [66.95s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acxgqxq - ignored: False]
# There were 270 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 282 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 247 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 313 divergences after tuning. Increase `target_accept` or reparameterize.
#   0%|          | 3/1634 [76.42s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aarphwc - ignored: False]
# There were 110 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 109 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 278 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 313 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 4/1634 [96.75s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acnnevs - ignored: False]
# There were 512 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 636 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 644 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 723 divergences after tuning. Increase `target_accept` or reparameterize.
#   0%|          | 5/1634 [104.71s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18abxbmqh - ignored: False]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
#   0%|          | 6/1634 [94.10s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abpbopt - ignored: False]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 19 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 18 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   0%|          | 8/1634 [78.79s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18acqyvag - ignored: False]
# There were 67 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 68 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 9/1634 [87.43s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aanesgt - ignored: False]
# There were 12 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 17 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 10/1634 [95.70s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19acfwynw - ignored: False]
# There were 498 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 399 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 441 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 479 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 11/1634 [89.43s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamrais - ignored: False]
# There were 248 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 267 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 158 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 123 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 12/1634 [118.22s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamhhiz - ignored: False]
# There were 88 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 90 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 13/1634 [98.34s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaynqaj - ignored: False]
# There were 100 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 103 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 166 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 164 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 15/1634 [68.87s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18aavjcpf - ignored: False]
# INFO (theano.gof.compilelock): Waiting for existing lock by process '31344' (I am process '31650')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/tesla/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.7.9-64/lock_dir
# There were 172 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 163 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 288 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 548 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   1%|          | 16/1634 [68.29s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aalbrgu - ignored: False]
# There were 349 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 352 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 430 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 477 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 17/1634 [86.82s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaeopgw - ignored: False]
# There were 224 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 239 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 262 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 243 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 18/1634 [114.16s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abaeyqw - ignored: False]
# There were 247 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 214 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 19/1634 [95.56s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18abshezu - ignored: False]
# There were 387 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 498 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# There were 32 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 59 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|          | 20/1634 [105.28s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aahbfmf - ignored: False]
# There were 260 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 211 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 166 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 147 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|▏         | 21/1634 [108.03s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19abuyuwa - ignored: False]
# There were 425 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 316 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 270 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 275 divergences after tuning. Increase `target_accept` or reparameterize.
#   1%|▏         | 22/1634 [98.45s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaruixj - ignored: False]
# There were 142 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 124 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 112 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 142 divergences after tuning. Increase `target_accept` or reparameterize.
#   2%|▏         | 25/1634 [54.05s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aayprqz - ignored: False]
# INFO (theano.gof.compilelock): Waiting for existing lock by process '31344' (I am process '31774')
# INFO (theano.gof.compilelock): To manually release the lock, delete /home/tesla/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.7.9-64/lock_dir
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 27/1634 [190.59s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaxfzao - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 28/1634 [172.75s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18aahatvc - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 32/1634 [140.71s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF18aaxcxih - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 33/1634 [152.28s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aagzchj - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 34/1634 [166.60s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aaumvig - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 35/1634 [159.95s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamtwwv - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 36/1634 [164.13s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aawmlfq - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 37/1634 [182.03s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF19aamhhae - ignored: False]
# The estimated number of effective samples is smaller than 200 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
#   2%|▏         | 38/1634 [164.81s/it, method: mcmc - add_original: True - set_name: train - lcobj_name: ZTF20aazwuin - ignored: False]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d53f2d0a14ba> in <module>
#      11         'save_rootdir':'../save',
#      12     }
# ---> 13     errors = generate_synthetic_dataset(lcdataset, 'train', obse_sampler_bdict, length_sampler_bdict, **sd_kwargs)
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/generators/synthetic_datasets.py in generate_synthetic_dataset(lcdataset, set_name, obse_sampler_bdict, length_sampler_bdict, method, synthetic_samples_per_curve, add_original, ignored_lcobj_names, save_rootdir)
#      35                                 lcobj = lcset[lcobj_name]
#      36                                 sne_generator = get_syn_sne_generator(method)(lcobj, class_names, band_names, obse_sampler_bdict, length_sampler_bdict)
# ---> 37                                 new_lcobjs, new_smooth_lcojbs, trace_bdict = sne_generator.sample_curves(synthetic_samples_per_curve)
#      38
#      39                                 ## save files and images
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/generators/synthetic_curves.py in sample_curves(self, n)
#     127                 trace_bdict = {}
#     128                 for b in self.band_names:
# --> 129                         new_lcobjbs, new_smooth_lcobjbs, trace = self.sample_curves_b(b, n)
#     130                         trace_bdict[b] = trace
#     131
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/generators/synthetic_curves.py in sample_curves_b(self, b, n)
#     152         def sample_curves_b(self, b, n):
#     153                 lcobjb = self.lcobj.get_b(b)
# --> 154                 trace = self.get_pm_trace_b(b, n)
#     155                 trace.get_fit_errors(lcobjb, self.func)
#     156                 trace.sort()
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/generators/synthetic_curves.py in get_pm_trace_b(self, b, n)
#     468                 try:
#     469                         lcobjb = self.lcobj.get_b(b).copy()
# --> 470                         pm_bounds = b_.get_pm_bounds(lcobjb, self.class_names, self.uses_new_bounds, self.min_required_points_to_fit)[self.c]
#     471                         #print('get_mcmc_trace')
#     472                         mcmc_trace = self.get_mcmc_trace(lcobjb, pm_bounds, n)
#
# ~/oscar/tesis/sne-lightcurves-synthetic/synthsne/generators/bounds.py in get_pm_bounds(lcobjb, class_names, uses_new_bounds, min_required_points)
#      17         ### checks
#      18         if len(days)<min_required_points:
# ---> 19                 raise ex.TooShortCurveError()
#      20
#      21         ### utils
#
# NameError: name 'ex' is not defined

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.plots import plot_obs_obse_scatter

plot_obs_obse_scatter(lcdataset, 'train', 'synth_train')

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import flamingchoripan.cutePlots.colors as cc
import flamingchoripan.cutePlots.plots as cplots

figsize = (12,5)
fig, ax = plt.subplots(1, 1, figsize=figsize)
for ks,set_name in enumerate(['synth_train']):
    lcset = lcdataset.get(set_name)
    lcobj_classes = lcset.get_lcobj_classes()
    to_plot = {'class samples':lcobj_classes}
    title = 'class population distribution\n'
    title += f'survey: {lcset.survey} - set: {set_name} - class samples: {len(lcobj_classes):,}'
    plt_kwargs = {
        'fig':fig,
        'ax':ax,
        'ylabel':'' if ks>0 else None,
        'legend_ncol':len(lcset.band_names),
        'title':title,
        'cmap':cc.colorlist_to_cmap([cc.NICE_COLORS_DICT['nice_gray']]),
        'uses_log_scale':0,
    }
    fig, ax = cplots.plot_hist_labels(to_plot, lcset.class_names, **plt_kwargs)
    
fig.tight_layout()
plt.plot()

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_synthetic_samples

plot_synthetic_samples(lcdataset, 'train', max_samples=1)

# %%
# %load_ext autoreload
# %autoreload 2
from src.umaps import get_fitted_umap, get_transformed_umap

set_name_train = 'train'
set_name_test = 'synth_train'
30
pm_umap_results = get_fitted_umap(lcdataset, set_name_test)
res = get_transformed_umap(lcdataset, pm_umap_results, set_name_train, set_name_test)
pm_args_embd_results_train, pm_args_embd_results_test = res

# %%
# %load_ext autoreload
# %autoreload 2
from src.plots import plot_2Dprojections

for c in [None]+lcdataset.raw.class_names:
    kwargs = {
        'target_class':c,
        #'x_mode':'x_pca',
        'x_mode':'x_umap',
        'x_mode':'x_tsne',
    }
    plot_2Dprojections(lcdataset, set_name_train, pm_args_embd_results_train, set_name_test, pm_args_embd_results_test, **kwargs)

# %%
from flamingchoripan.myUtils.files import load_pickle, save_pickle
from src import C_

assert 0
save_filedir = f'{root_folder}/{cfilename}.{C_.EXT_PARAMETRIC_LIGHTCURVE}'
save_pickle(save_filedir, lcdataset)
