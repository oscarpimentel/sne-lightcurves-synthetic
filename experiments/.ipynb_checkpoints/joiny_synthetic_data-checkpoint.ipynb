# %%
import sys
sys.path.append('../') # or just install the module
sys.path.append('../../flaming-choripan') # or just install the module
sys.path.append('../../astro-lightcurves-handler') # or just install the module

# %%
from flamingchoripan.files import search_for_filedirs
from synthsne import C_

rootdir = '../../surveys-save'
filedirs = search_for_filedirs(rootdir, fext=C_.EXT_SPLIT_LIGHTCURVE)
# Out:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# found filedirs: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-mcmc.splcds - 53.495[mbs]
# (1) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-linear.splcds - 125.863[mbs]
# (2) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-bspline.splcds - 125.363[mbs]
# (3) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-curvefit.splcds - 133.656[mbs]
# (4) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-uniformprior.splcds - 138.538[mbs]
# (5) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 7.056[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# filedirs after searching with filters: (../../surveys-save)
# (0) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-mcmc.splcds - 53.495[mbs]
# (1) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-linear.splcds - 125.863[mbs]
# (2) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-bspline.splcds - 125.363[mbs]
# (3) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-curvefit.splcds - 133.656[mbs]
# (4) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-uniformprior.splcds - 138.538[mbs]
# (5) - ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe.splcds - 7.056[mbs]
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from flamingchoripan.files import load_pickle, save_pickle
from flamingchoripan.files import get_dict_from_filedir
from lchandler import C_

def load_lcdataset(filename):
    assert filename.split('.')[-1]==C_.EXT_SPLIT_LIGHTCURVE
    return load_pickle(filename)

method = 'mcmc'
filedir = f'../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-{method}.splcds'

filedic = get_dict_from_filedir(filedir)
root_folder = filedic['*rootdir*']
cfilename = filedic['*cfilename*']
survey = filedic['survey']
lcdataset = load_lcdataset(filedir)
print(lcdataset['raw'].keys())
print(lcdataset['raw'].get_random_lcobj(False).keys())
print(lcdataset)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# > loading: ../../surveys-save/alerceZTFv7.1/survey-alerceZTFv7.1_bands-gr_mode-onlySNe_method-mcmc.splcds
# dict_keys(['data', 'survey', 'description', 'band_names', 'class_names', 'obs_is_flux'])
# dict_keys(['days', 'obs', 'obse', 'y', 'synthetic'])
# LCDataset:
# [outliers - samples 14]
# (*) obs_samples: 714 - min_len: 10 - max_dur: 412.9[days] - dur(p50): 128.8[days] - cadence(p50): 0.9[days]
# (g) obs_samples: 344 - min_len: 3 - max_dur: 408.0[days] - dur(p50): 127.8[days] - cadence(p50): 2.9[days]
# (r) obs_samples: 370 - min_len: 6 - max_dur: 376.0[days] - dur(p50): 100.3[days] - cadence(p50): 3.0[days]
#    |█▏      | SLSN - 2/14 (14.29%)
#    |        | SNIa - 0/14 (0.00%)
#    |██▊     | SNIbc - 5/14 (35.71%)
#    |████    | allSNII - 7/14 (50.00%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [raw - samples 2,033]
# (*) obs_samples: 64,460 - min_len: 6 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 28,007 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 38.8[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 36,453 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 50.8[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 31/2,033 (1.52%)
#    |██████  | SNIa - 1,534/2,033 (75.45%)
#    |▍       | SNIbc - 98/2,033 (4.82%)
#    |█▍      | allSNII - 370/2,033 (18.20%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train - samples 1,297]
# (*) obs_samples: 40,741 - min_len: 3 - max_dur: 538.8[days] - dur(p50): 52.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 17,696 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 39.0[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 23,045 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 50.0[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 19/1,297 (1.46%)
#    |██████  | SNIa - 980/1,297 (75.56%)
#    |▍       | SNIbc - 62/1,297 (4.78%)
#    |█▍      | allSNII - 236/1,297 (18.20%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [val - samples 322]
# (*) obs_samples: 9,294 - min_len: 6 - max_dur: 362.0[days] - dur(p50): 51.0[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 3,996 - min_len: 0 - max_dur: 359.1[days] - dur(p50): 36.9[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 5,298 - min_len: 0 - max_dur: 362.0[days] - dur(p50): 49.0[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 4/322 (1.24%)
#    |██████  | SNIa - 245/322 (76.09%)
#    |▎       | SNIbc - 15/322 (4.66%)
#    |█▍      | allSNII - 58/322 (18.01%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [test - samples 412]
# (*) obs_samples: 13,506 - min_len: 6 - max_dur: 443.9[days] - dur(p50): 54.0[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 5,966 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 38.4[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 7,540 - min_len: 0 - max_dur: 443.9[days] - dur(p50): 52.9[days] - cadence(p50): 2.9[days]
#    |▏       | SLSN - 8/412 (1.94%)
#    |█████▉  | SNIa - 308/412 (74.76%)
#    |▍       | SNIbc - 21/412 (5.10%)
#    |█▍      | allSNII - 75/412 (18.20%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train+val - samples 1,619]
# (*) obs_samples: 50,035 - min_len: 3 - max_dur: 538.8[days] - dur(p50): 51.9[days] - cadence(p50): 1.0[days]
# (g) obs_samples: 21,692 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 38.1[days] - cadence(p50): 3.0[days]
# (r) obs_samples: 28,343 - min_len: 0 - max_dur: 538.8[days] - dur(p50): 49.9[days] - cadence(p50): 3.0[days]
#    |        | SLSN - 23/1,619 (1.42%)
#    |██████  | SNIa - 1,225/1,619 (75.66%)
#    |▍       | SNIbc - 77/1,619 (4.76%)
#    |█▍      | allSNII - 294/1,619 (18.16%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [train+val[mcmc] - samples 38,741]
# (*) obs_samples: 1,132,251 - min_len: 4 - max_dur: 387.1[days] - dur(p50): 60.2[days] - cadence(p50): 2.2[days]
# (g) obs_samples: 505,824 - min_len: 0 - max_dur: 384.3[days] - dur(p50): 44.7[days] - cadence(p50): 3.1[days]
# (r) obs_samples: 626,427 - min_len: 0 - max_dur: 355.0[days] - dur(p50): 57.4[days] - cadence(p50): 3.1[days]
#    |▎       | SLSN - 1,235/38,741 (3.19%)
#    |███████▋| SNIa - 37,506/38,741 (96.81%)
#    |        | SNIbc - 0/38,741 (0.00%)
#    |        | allSNII - 0/38,741 (0.00%)
# ────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
# %load_ext autoreload
# %autoreload 2
from lchandler.plots.scatters import plot_obs_obse_scatter # to lchandler?

#plot_obs_obse_scatter(lcdataset, 'train', 'train_curvefit', n=2000)
plot_ndict = {
    f'train+val':None,
    f'train+val[{method}]':5e3,
}
plot_obs_obse_scatter(lcdataset, list(plot_ndict.keys()), plot_ndict=plot_ndict)
#plot_values_distribution(lcdataset, 'train', 'obs')
#plot_values_distribution(lcdataset, 'train_curvefit', 'obs')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
